# %%
import pandas as pd
import numpy as np
print("DataFrame.applyfunction:\n")
info=pd.DataFrame([[2,7]]*3,columns=['P','Q'])
print("\nOrigibnal DataFrame:\n",info)
print("\nSquare rppt of DataFrame:\n",info.apply(np.sqrt))
print("\nSum of each column:\n",info.apply(np.sum,axis=0))
print("\nSum of each row:\n",info.apply(np.sum,axis=1))
# Out:
# DataFrame.applyfunction:
#
#
# Origibnal DataFrame:
#     P  Q
# 0  2  7
# 1  2  7
# 2  2  7
#
# Square rppt of DataFrame:
#            P         Q
# 0  1.414214  2.645751
# 1  1.414214  2.645751
# 2  1.414214  2.645751
#
# Sum of each column:
#  P     6
# Q    21
# dtype: int64
#
# Sum of each row:
#  0    9
# 1    9
# 2    9
# dtype: int64

# %%
info-pd.DataFrame([[1,5,7],[2,7,8],[3,6,9]],columns=['X','Y','Z'])
print("\n Original DataFrame:\n",info)
print("\nMinimum and maximum of each column:\n")
print(info.agg(['min','max']))
# Out:
#  Original DataFrame:
#     X  Y  Z
# 0  1  5  7
# 1  2  7  8
# 2  3  6  9
#
# Minimum and maximum of each column:
#
#      X  Y  Z
# min  1  5  7
# max  3  7  9

# %%
print("\nDataFrame.Assign function:\n")
d2=pd.DataFrame([['Duraisingham',123],['sanjayraj',143]],columns=['Emp','ID'])
print("\nOriginal DataFrame:\n",d2);d2['Age']=[35,40]
print("\nAdding new column:\n",d2)
d=d2.assign(sex=['Male','Female'])
print("\mAdding new column:\n",d)
# Out:
# DataFrame.Assign function:
#
#
# Original DataFrame:
#              Emp   ID
# 0  Duraisingham  123
# 1     sanjayraj  143
#
# Adding new column:
#              Emp   ID  Age
# 0  Duraisingham  123   35
# 1     sanjayraj  143   40
# \mAdding new column:
#              Emp   ID  Age     sex
# 0  Duraisingham  123   35    Male
# 1     sanjayraj  143   40  Female

# %%
print("\nDataFrame.sort function:\n")
info=pd.DataFrame(np.random.randn(5,2),index=[3,2,0,4,1],columns = ['col3','col4'])
print(info)
info2=info.sort_index()
print("\nSort.index:\n",info2)
info3=info
# Out:
# DataFrame.sort function:
#
#        col3      col4
# 3  0.567752  0.223039
# 2 -0.289240 -0.482175
# 0  0.157475  1.016169
# 4  0.574421  0.601425
# 1 -0.905616 -0.087512

# %%
print("\nDataFrame.Merge function:\n")
left = pd.DataFrame({'id':[1,2,3,4,5],'Name':['Alex','Amy','Allen','Alice','Ayoung'],'sub':['sub1','sub2','sub4','sub6','sub5']})
right=pd.DataFrame({'id':[1,2,3,4,5],'Name':['','Amy','Allen','Alice','Ayoung'],'sub':['sub1','sub2','sub4','sub6','sub5']})
