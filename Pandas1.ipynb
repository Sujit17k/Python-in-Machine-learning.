# %%
import pandas as pd
df=pd.DataFrame()
print(df)
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
cmp=pd.Series(['parker','John','Smith','William'])
id=pd.Series([102,107,109,114])
frame={'Emp':cmp,'ID':id}
result = pd.DataFrame(frame)
print("\nSeries to Data Frame\n")
print(result)
# Out:
# Series to Data Frame
#
#        Emp   ID
# 0   parker  102
# 1     John  107
# 2    Smith  109
# 3  William  114

# %%
print("\nAdding new column:\n")
result['Age']=pd.Series([35,24,40,38])
print(result)
# Out:
# Adding new column:
#
#        Emp   ID  Age
# 0   parker  102   35
# 1     John  107   24
# 2    Smith  109   40
# 3  William  114   38

# %%
print("\nDeleting one column:\n")
del result['Age']
print(result)
# Out:
# Deleting one column:
#
#        Emp   ID
# 0   parker  102
# 1     John  107
# 2    Smith  109
# 3  William  114

# %%
print("\nExtracting the third row:\n")
print(result.loc[2])
# Out:
# Extracting the third row:
#
# Emp    Smith
# ID       109
# Name: 2, dtype: object

# %%
print("\nSlice rows:\n", result[1:3])
# Out:
# Slice rows:
#       Emp   ID
# 1   John  107
# 2  Smith  109

# %%
d2=pd.DataFrame([['Munusaamy',123],['Margazhy',143]],columns=['Emp','ID'])
print("\nAdding new row values:\n",result.append(d2))
# Out:
# Adding new row values:
#           Emp   ID
# 0     parker  102
# 1       John  107
# 2      Smith  109
# 3    William  114
# 0  Munusaamy  123
# 1   Margazhy  143
# C:\Users\DELL\AppData\Local\Temp\ipykernel_14464\1069780351.py:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   print("\nAdding new row values:\n",result.append(d2))

# %%
print("\nDeleting particular row:\n" , result.drop(1))
# Out:
# Deleting particular row:
#         Emp   ID
# 0   parker  102
# 2    Smith  109
# 3  William  114
